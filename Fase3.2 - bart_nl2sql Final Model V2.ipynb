# %%
import os
import json
import torch
import random
from google.colab import drive
from torch.utils.data import Dataset, DataLoader
from transformers import AutoTokenizer, BartForConditionalGeneration, Trainer, TrainingArguments, EarlyStoppingCallback
from torch.optim.lr_scheduler import CosineAnnealingLR
from torch.optim import AdamW

# %% [markdown]
# Montar disco

# %%
drive.mount('/content/drive')
SPIDER_PATH = "/content/drive/My Drive/spider"
# Out:
# Mounted at /content/drive

# %% [markdown]
# Cargar entrenamiento

# %%
def load_data(filepath):
    with open(filepath, "r") as f:
        return json.load(f)

train_data = load_data(f"{SPIDER_PATH}/train_spider.json")
val_data = load_data(f"{SPIDER_PATH}/dev.json")

# Cargar metadata de esquemas
schema_metadata = load_data(f"{SPIDER_PATH}/tables.json")

# %% [markdown]
# Cargar Metadata Esquemas

# %%
schema_metadata = load_data(f"{SPIDER_PATH}/tables.json")

# Función para obtener el esquema correcto
def get_schema_info(db_id, schema_metadata):
    for schema in schema_metadata:
        if schema["db_id"] == db_id:
            return json.dumps(schema)  # Convertir a string JSON para mejor manejo
    return ""

# %% [markdown]
# Pre procesar datos

# %%
def preprocess_spider(data, schema_metadata):
    inputs = []
    targets = []
    for item in data:
        question = item["question"]
        sql_query = item["query"]
        db_id = item["db_id"]
        schema_info = get_schema_info(db_id, schema_metadata)
        inputs.append(f"Schema: {schema_info} \n Translate to SQL: {question}")
        targets.append(sql_query)
    return inputs, targets

train_inputs, train_targets = preprocess_spider(train_data, schema_metadata)
val_inputs, val_targets = preprocess_spider(val_data, schema_metadata)

# %% [markdown]
# Tokenizar Datos

# %%
MODEL_NAME = "SwastikM/bart-large-nl2sql"
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)

def tokenize_data(inputs, targets, tokenizer, max_input_len=512, max_target_len=128):
    model_inputs = tokenizer(inputs, padding="max_length", truncation=True, max_length=max_input_len, return_tensors="pt")
    labels = tokenizer(targets, padding="max_length", truncation=True, max_length=max_target_len, return_tensors="pt").input_ids
    return model_inputs, labels

train_encodings, train_labels = tokenize_data(train_inputs, train_targets, tokenizer)
val_encodings, val_labels = tokenize_data(val_inputs, val_targets, tokenizer)

# %% [markdown]
# Dataset Personalizado

# %%
class SpiderDataset(Dataset):
    def __init__(self, encodings, labels):
        self.encodings = encodings
        self.labels = labels

    def __len__(self):
        return len(self.encodings["input_ids"])

    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        item["labels"] = torch.tensor(self.labels[idx])
        return item

train_dataset = SpiderDataset(train_encodings, train_labels)
val_dataset = SpiderDataset(val_encodings, val_labels)

# %% [markdown]
# Cargar Modelo

# %%
model = BartForConditionalGeneration.from_pretrained(MODEL_NAME)
# Out:
# config.json:   0%|          | 0.00/1.70k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/406 [00:00<?, ?B/s]

# %% [markdown]
# Optimizador configuracion

# %%
optimizer = AdamW(model.parameters(), lr=3e-5)

# %% [markdown]
# Scheduler con CosineAnnealingLR

# %%
scheduler = CosineAnnealingLR(optimizer, T_max=10)

# %% [markdown]
# Parametrizacion del entrenamiento

# %%
training_args = TrainingArguments(
    output_dir="/content/drive/My Drive/bart_nl2sql_finetuned",
    evaluation_strategy="epoch",
    save_strategy="epoch",
    learning_rate=3e-5,
    per_device_train_batch_size=8,
    per_device_eval_batch_size=8,
    gradient_accumulation_steps=8,
    weight_decay=0.05,
    warmup_steps=500,
    logging_dir="/content/drive/My Drive/logs",
    logging_steps=50,
    save_total_limit=2,
    num_train_epochs=20,  # Aumentado a 20 para mejor convergencia
    fp16=True,  # Activar entrenamiento en precisión mixta
    report_to="none",
    load_best_model_at_end=True,
    metric_for_best_model="eval_loss",
    greater_is_better=False,
    save_on_each_node=True,
)
# Out:
# /usr/local/lib/python3.11/dist-packages/transformers/training_args.py:1575: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(

# %% [markdown]
# Scheduler para reducir el learning rate

# %% [markdown]
# Early Stop

# %%
# Entrenador con Early Stopping
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset,
    optimizers=(optimizer, scheduler),
    callbacks=[EarlyStoppingCallback(early_stopping_patience=3)],
)

# %% [markdown]
# Entrenador

# %% [markdown]
# Aplicar Entrenamiento

# %%
trainer.train()
# Out:
# <ipython-input-10-757293780ece>:10: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# <ipython-input-10-757293780ece>:11: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item["labels"] = torch.tensor(self.labels[idx])
#     <div>
#
#       <progress value='550' max='2180' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 550/2180 10:19 < 30:43, 0.88 it/s, Epoch 5/20]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.430500</td>
#       <td>0.289919</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.150500</td>
#       <td>0.254121</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.104800</td>
#       <td>0.260711</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.084400</td>
#       <td>0.270017</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.070500</td>
#       <td>0.281278</td>
#     </tr>
#   </tbody>
# </table><p>
# /usr/local/lib/python3.11/dist-packages/transformers/modeling_utils.py:2758: UserWarning: Moving the following attributes in the config to the generation config: {'max_length': 142, 'min_length': 56, 'early_stopping': True, 'num_beams': 4, 'length_penalty': 2.0, 'no_repeat_ngram_size': 3, 'forced_bos_token_id': 0}. You are seeing this warning because you've set generation parameters in the model config, as opposed to in the generation config.
#   warnings.warn(
# <ipython-input-10-757293780ece>:10: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# <ipython-input-10-757293780ece>:11: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item["labels"] = torch.tensor(self.labels[idx])
# <ipython-input-10-757293780ece>:10: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# <ipython-input-10-757293780ece>:11: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item["labels"] = torch.tensor(self.labels[idx])
# <ipython-input-10-757293780ece>:10: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# <ipython-input-10-757293780ece>:11: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item["labels"] = torch.tensor(self.labels[idx])
# <ipython-input-10-757293780ece>:10: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# <ipython-input-10-757293780ece>:11: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item["labels"] = torch.tensor(self.labels[idx])
# There were missing keys in the checkpoint model loaded: ['model.encoder.embed_tokens.weight', 'model.decoder.embed_tokens.weight', 'lm_head.weight'].
# TrainOutput(global_step=550, training_loss=0.44283507737246425, metrics={'train_runtime': 621.9177, 'train_samples_per_second': 225.11, 'train_steps_per_second': 3.505, 'total_flos': 3.792433053696e+16, 'train_loss': 0.44283507737246425, 'epoch': 5.0})

# %% [markdown]
# Guardar Modelo

# %%
model.save_pretrained("/content/drive/My Drive/bart_nl2sql_finetuned/final_model2")
tokenizer.save_pretrained("/content/drive/My Drive/bart_nl2sql_finetuned/final_model2")
# Out:
# ('/content/drive/My Drive/bart_nl2sql_finetuned/final_model2/tokenizer_config.json',
#  '/content/drive/My Drive/bart_nl2sql_finetuned/final_model2/special_tokens_map.json',
#  '/content/drive/My Drive/bart_nl2sql_finetuned/final_model2/vocab.json',
#  '/content/drive/My Drive/bart_nl2sql_finetuned/final_model2/merges.txt',
#  '/content/drive/My Drive/bart_nl2sql_finetuned/final_model2/added_tokens.json',
#  '/content/drive/My Drive/bart_nl2sql_finetuned/final_model2/tokenizer.json')

# %% [markdown]
# Metricas de Evaluacion

# %%
# Evaluar modelo y mostrar métricas
eval_results = trainer.evaluate()
print("Resultados de Evaluación:")
for key, value in eval_results.items():
    print(f"{key}: {value}")
# Out:
# <ipython-input-10-757293780ece>:10: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# <ipython-input-10-757293780ece>:11: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item["labels"] = torch.tensor(self.labels[idx])
#     <div>
#
#       <progress value='130' max='130' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [130/130 00:05]
#     </div>
# Resultados de Evaluación:
# eval_loss: 0.2541213929653168
# eval_runtime: 5.1204
# eval_samples_per_second: 201.936
# eval_steps_per_second: 25.388
# epoch: 5.0

# %% [markdown]
# Prueba de preguntas aleatorias
